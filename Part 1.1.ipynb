# %%
import math, numpy
#Part 1 input data: Air temp (degC), ID (W/sqm), load resistance (ohms)
# - split into training set and a randomly slected small validation set
xdata = [[-10.0, 350, 4.464], 
  [-10.0, 650, 4.464], 
  [-10.0, 950, 4.464], 
  [-10.0, 1250, 4.464], 
  [10.0, 350, 4.464], 
  [10.0, 650, 4.464], 
  [10.0, 950, 4.464], 
  [10.0, 1250, 4.464], 
  [30.0, 350, 4.464], 
  [30.0, 650, 4.464], 
  [30.0, 950, 4.464], 
  [30.0, 1250, 4.464], 
  [-10.0, 350, 6.696], 
  [-10.0, 650, 6.696], 
  [-10.0, 950, 6.696], 
  [-10.0, 1250, 6.696], 
  [10.0, 350, 6.696], 
  [10.0, 650, 6.696], 
  [10.0, 950, 6.696], 
  [10.0, 1250, 6.696], 
  [30.0, 350, 6.696], 
  [30.0, 650, 6.696], 
  [30.0, 950, 6.696], 
  [30.0, 1250, 6.696], 
  [-10.0, 350, 8.928], 
  [-10.0, 650, 8.928], 
  [-10.0, 950, 8.928], 
  [-10.0, 1250, 8.928], 
  [10.0, 350, 8.928], 
  [10.0, 650, 8.928], 
  [10.0, 950, 8.928], 
  [10.0, 1250, 8.928], 
  [30.0, 350, 8.928], 
  [30.0, 650, 8.928], 
  [30.0, 950, 8.928], 
  [30.0, 1250, 8.928]] 


#Part 1 output data: VL (V) and Power out (W)
ydata = [[18.9, 80.3], 
 [23.5, 124.6], 
 [24.8, 138.6], 
 [25.6, 146.9], 
 [19.2, 83.1], 
 [25.0, 140.5], 
 [26.5, 157.6], 
 [27.3, 167.5],  
 [19.4, 84.7], 
 [26.4, 156.7], 
 [28.1, 177.7], 
 [29.0, 189.4],
 [22.4, 75.2], 
 [24.8, 92.2], 
 [25.8, 99.7], 
 [26.4, 104.6], 
 [23.6, 83.7], 
 [26.5, 104.9], 
 [27.6, 113.8], 
 [28.3, 119.6], 
 [24.8, 92.0], 
 [28.1, 118.2], 
 [29.3, 128.8], 
 [30.1, 135.5],  
 [23.5, 62.2], 
 [25.4, 72.5], 
 [26.3, 77.6], 
 [26.9, 81.1],  
 [25.0, 70.3], 
 [27.1, 82.7], 
 [28.1, 88.7], 
 [28.7, 92.8],  
 [26.5, 78.6], 
 [28.8, 93.5], 
 [29.9, 100.5], 
 [30.6, 105.2]] 


xarray= numpy.array(xdata)
yarray= numpy.array(ydata)
print (xdata)
print (xarray)
print (ydata)
print (yarray)
# Out:
# [[-10.0, 350, 4.464], [-10.0, 650, 4.464], [-10.0, 950, 4.464], [-10.0, 1250, 4.464], [10.0, 350, 4.464], [10.0, 650, 4.464], [10.0, 950, 4.464], [10.0, 1250, 4.464], [30.0, 350, 4.464], [30.0, 650, 4.464], [30.0, 950, 4.464], [30.0, 1250, 4.464], [-10.0, 350, 6.696], [-10.0, 650, 6.696], [-10.0, 950, 6.696], [-10.0, 1250, 6.696], [10.0, 350, 6.696], [10.0, 650, 6.696], [10.0, 950, 6.696], [10.0, 1250, 6.696], [30.0, 350, 6.696], [30.0, 650, 6.696], [30.0, 950, 6.696], [30.0, 1250, 6.696], [-10.0, 350, 8.928], [-10.0, 650, 8.928], [-10.0, 950, 8.928], [-10.0, 1250, 8.928], [10.0, 350, 8.928], [10.0, 650, 8.928], [10.0, 950, 8.928], [10.0, 1250, 8.928], [30.0, 350, 8.928], [30.0, 650, 8.928], [30.0, 950, 8.928], [30.0, 1250, 8.928]]
# [[ -10.     350.       4.464]
#  [ -10.     650.       4.464]
#  [ -10.     950.       4.464]
#  [ -10.    1250.       4.464]
#  [  10.     350.       4.464]
#  [  10.     650.       4.464]
#  [  10.     950.       4.464]
#  [  10.    1250.       4.464]
# ...

# %%
T=[]
I=[]
R=[]
for i in range (len(xdata)):
    T.append(xdata[i][0])
    I.append(xdata[i][1])
    R.append(xdata[i][2])
T.sort()
I.sort()
R.sort()
print(T)
print(I)
print(R)
# Out:
# [-10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, -10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0]
# [350, 350, 350, 350, 350, 350, 350, 350, 350, 650, 650, 650, 650, 650, 650, 650, 650, 650, 950, 950, 950, 950, 950, 950, 950, 950, 950, 1250, 1250, 1250, 1250, 1250, 1250, 1250, 1250, 1250]
# [4.464, 4.464, 4.464, 4.464, 4.464, 4.464, 4.464, 4.464, 4.464, 4.464, 4.464, 4.464, 6.696, 6.696, 6.696, 6.696, 6.696, 6.696, 6.696, 6.696, 6.696, 6.696, 6.696, 6.696, 8.928, 8.928, 8.928, 8.928, 8.928, 8.928, 8.928, 8.928, 8.928, 8.928, 8.928, 8.928]

# %%
V=[]
W=[]
for i in range (len(ydata)):
    V.append(ydata[i][0])
    W.append(ydata[i][1])
V.sort()
W.sort()
print(V)
print(W)
# Out:
# [18.9, 19.2, 19.4, 22.4, 23.5, 23.5, 23.6, 24.8, 24.8, 24.8, 25.0, 25.0, 25.4, 25.6, 25.8, 26.3, 26.4, 26.4, 26.5, 26.5, 26.5, 26.9, 27.1, 27.3, 27.6, 28.1, 28.1, 28.1, 28.3, 28.7, 28.8, 29.0, 29.3, 29.9, 30.1, 30.6]
# [62.2, 70.3, 72.5, 75.2, 77.6, 78.6, 80.3, 81.1, 82.7, 83.1, 83.7, 84.7, 88.7, 92.0, 92.2, 92.8, 93.5, 99.7, 100.5, 104.6, 104.9, 105.2, 113.8, 118.2, 119.6, 124.6, 128.8, 135.5, 138.6, 140.5, 146.9, 156.7, 157.6, 167.5, 177.7, 189.4]

# %%
def median(x):
    return (x[int(len(x)/2)-1]+x[int(len(x)/2)])/2

# %%
print("Median T =",median(T))
print("Median I =",median(I))
print("Median R =",median(R))
print("Median V =",median(V))
print("Median W =",median(W))
# Out:
# Median T = 10.0
# Median I = 800.0
# Median R = 6.696
# Median V = 26.45
# Median W = 100.1

# %%
xdata_normalized=[]
for i in range (len(xdata)):
    xdata_normalized.append([xdata[i][0]/median(T),xdata[i][1]/median(I),xdata[i][2]/median(R)])
for j in range (len(xdata_normalized)):
    print(xdata_normalized[j])
# Out:
# [-1.0, 0.4375, 0.6666666666666667]
# [-1.0, 0.8125, 0.6666666666666667]
# [-1.0, 1.1875, 0.6666666666666667]
# [-1.0, 1.5625, 0.6666666666666667]
# [1.0, 0.4375, 0.6666666666666667]
# [1.0, 0.8125, 0.6666666666666667]
# [1.0, 1.1875, 0.6666666666666667]
# [1.0, 1.5625, 0.6666666666666667]
# [3.0, 0.4375, 0.6666666666666667]
# [3.0, 0.8125, 0.6666666666666667]
# [3.0, 1.1875, 0.6666666666666667]
# [3.0, 1.5625, 0.6666666666666667]
# [-1.0, 0.4375, 1.0]
# [-1.0, 0.8125, 1.0]
# [-1.0, 1.1875, 1.0]
# [-1.0, 1.5625, 1.0]
# [1.0, 0.4375, 1.0]
# [1.0, 0.8125, 1.0]
# [1.0, 1.1875, 1.0]
# [1.0, 1.5625, 1.0]
# [3.0, 0.4375, 1.0]
# [3.0, 0.8125, 1.0]
# [3.0, 1.1875, 1.0]
# [3.0, 1.5625, 1.0]
# [-1.0, 0.4375, 1.3333333333333335]
# [-1.0, 0.8125, 1.3333333333333335]
# [-1.0, 1.1875, 1.3333333333333335]
# [-1.0, 1.5625, 1.3333333333333335]
# [1.0, 0.4375, 1.3333333333333335]
# [1.0, 0.8125, 1.3333333333333335]
# [1.0, 1.1875, 1.3333333333333335]
# [1.0, 1.5625, 1.3333333333333335]
# ...

# %%
ydata_normalized=[]
for i in range (len(ydata)):
    ydata_normalized.append([ydata[i][0]/median(V),ydata[i][1]/median(W)])
for j in range (len(ydata_normalized)):
    print(ydata_normalized[j])
# Out:
# [0.7145557655954631, 0.8021978021978022]
# [0.888468809073724, 1.2447552447552448]
# [0.9376181474480152, 1.3846153846153846]
# [0.9678638941398866, 1.4675324675324677]
# [0.725897920604915, 0.8301698301698301]
# [0.945179584120983, 1.4035964035964037]
# [1.001890359168242, 1.5744255744255744]
# [1.0321361058601135, 1.6733266733266734]
# [0.7334593572778828, 0.8461538461538463]
# [0.998109640831758, 1.5654345654345654]
# [1.062381852551985, 1.7752247752247752]
# [1.0964083175803403, 1.8921078921078922]
# [0.8468809073724007, 0.7512487512487513]
# [0.9376181474480152, 0.9210789210789212]
# [0.9754253308128545, 0.9960039960039961]
# [0.998109640831758, 1.0449550449550449]
# [0.892249527410208, 0.8361638361638363]
# [1.001890359168242, 1.047952047952048]
# [1.0434782608695652, 1.136863136863137]
# [1.0699432892249527, 1.1948051948051948]
# [0.9376181474480152, 0.9190809190809192]
# [1.062381852551985, 1.180819180819181]
# [1.1077504725897922, 1.2867132867132869]
# ...

# %%
import random

training_dataX = []
validation_dataX = []
training_dataY = []
validation_dataY = []

r=[i for i in range(len(xdata_normalized))]

training_index=[]
validation_index=r

for k in range(int(len(r)*(2/3))):
    n = random.choice(r)
    training_index.append(n)
    validation_index.remove(n)
    
for i in training_index:
    training_dataX.append(xdata_normalized[i])
    training_dataY.append(ydata_normalized[i])

for i in validation_index:
    validation_dataX.append(xdata_normalized[i])
    validation_dataY.append(ydata_normalized[i])

# %%
print("Training Set X:",training_dataX)
print("Validation Set X:",validation_dataX)
print("Training Set Y:",training_dataY)
print("Validation Set Y:",validation_dataY)
# Out:
# Training Set X: [[1.0, 0.8125, 1.3333333333333335], [3.0, 0.4375, 0.6666666666666667], [1.0, 1.5625, 1.0], [3.0, 1.5625, 1.0], [1.0, 0.4375, 1.3333333333333335], [3.0, 0.8125, 0.6666666666666667], [1.0, 0.4375, 1.0], [3.0, 1.1875, 1.0], [-1.0, 0.4375, 0.6666666666666667], [3.0, 1.5625, 1.3333333333333335], [-1.0, 0.4375, 1.0], [3.0, 1.1875, 1.3333333333333335], [1.0, 1.1875, 1.3333333333333335], [3.0, 0.8125, 1.0], [3.0, 1.5625, 0.6666666666666667], [-1.0, 0.4375, 1.3333333333333335], [1.0, 0.4375, 0.6666666666666667], [1.0, 1.5625, 0.6666666666666667], [-1.0, 0.8125, 1.3333333333333335], [-1.0, 1.1875, 1.0], [1.0, 1.5625, 1.3333333333333335], [-1.0, 1.5625, 1.3333333333333335], [-1.0, 1.1875, 0.6666666666666667], [3.0, 0.8125, 1.3333333333333335]]
# ...

# %%
#Neural Network 
#import useful packages
from tensorflow import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf

#the follwoing 2 lines are only needed for Mac OS machines
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# define meadian values of input variables - add your values here
Tamed = median(T)  #make sure Tamed does not = 0
IDmed = median(I)
RLmed = median(R)

#create input data array
xarray= np.array(training_dataX)
print (training_dataX)
print (xarray)

# define meadian values of output variables - add your values here
VLmed = median(V)
Wdmed = median(W)

#create output data array
yarray= np.array(training_dataY)
print (training_dataY)
print (yarray)
# Out:
# [[1.0, 0.8125, 1.3333333333333335], [3.0, 0.4375, 0.6666666666666667], [1.0, 1.5625, 1.0], [3.0, 1.5625, 1.0], [1.0, 0.4375, 1.3333333333333335], [3.0, 0.8125, 0.6666666666666667], [1.0, 0.4375, 1.0], [3.0, 1.1875, 1.0], [-1.0, 0.4375, 0.6666666666666667], [3.0, 1.5625, 1.3333333333333335], [-1.0, 0.4375, 1.0], [3.0, 1.1875, 1.3333333333333335], [1.0, 1.1875, 1.3333333333333335], [3.0, 0.8125, 1.0], [3.0, 1.5625, 0.6666666666666667], [-1.0, 0.4375, 1.3333333333333335], [1.0, 0.4375, 0.6666666666666667], [1.0, 1.5625, 0.6666666666666667], [-1.0, 0.8125, 1.3333333333333335], [-1.0, 1.1875, 1.0], [1.0, 1.5625, 1.3333333333333335], [-1.0, 1.5625, 1.3333333333333335], [-1.0, 1.1875, 0.6666666666666667], [3.0, 0.8125, 1.3333333333333335]]
# [[ 1.          0.8125      1.33333333]
#  [ 3.          0.4375      0.66666667]
#  [ 1.          1.5625      1.        ]
#  [ 3.          1.5625      1.        ]
#  [ 1.          0.4375      1.33333333]
#  [ 3.          0.8125      0.66666667]
# ...

# %%
# define neural network model

#As seen below, we have created four dense layers. 
#A dense layer is a layer in neural network that’s fully connected. 
#In other words, all the neurons in one layer are connected to all other neurons in the next layer.
#In the first layer, we need to provide the input shape, which is 1 in our case. 
#The activation function we have chosen is elu, which stands for exponential linear unit. .

from keras import backend as K
#initialize weights with values between -0.2 and 0.5
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.5)

model = keras.Sequential([
    keras.layers.Dense(6, activation=K.elu, input_shape=[3],  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(16, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(2,  kernel_initializer=initializer)
  ])

# %%
#We’re using RMSprop as our optimizer here. RMSprop stands for Root Mean Square Propagation. 
#It’s one of the most popular gradient descent optimization algorithms for deep learning networks. 
#RMSprop is an optimizer that’s reliable and fast.
#We’re compiling the mode using the model.compile function. The loss function used here 
#is mean squared error. After the compilation of the model, we’ll use the fit method with ~500 epochs.
#Number of epochs can be varied.

#from tf.keras import optimizers
rms = keras.optimizers.RMSprop(0.020)
model.compile(loss='mean_absolute_error',optimizer=rms)

# %%
#After the compilation of the model, we’ll use the fit method with 500 epochs.
#I started with epochs value of 100 and then tested the model after training. 
#The prediction was not that good. Then I modified the number of epochs to 200 and tested the model again. 
#Accuracy had improved slightly, but figured I’d give it one more try. Finally, at 500 epochs 
#I found acceptable prediction accuracy.

#The fit method takes three parameters; namely, x, y, and number of epochs. 
#During model training, if all the batches of data are seen by the model once, 
#we say that one epoch has been completed.

# Add an early stopping callback
es = keras.callbacks.EarlyStopping(
    monitor='loss', 
    mode='min', 
    patience = 80, 
    restore_best_weights = True, 
    verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss', 
                     mode='min',  verbose=1, save_best_only=True)

historyData = model.fit(xarray,yarray,epochs=800,callbacks=[es])

loss_hist = historyData.history['loss']
#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))

model.save('./best_model')
# Out:
# Epoch 1/800
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0561
# Epoch 2/800
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0496
# Epoch 3/800
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0487
# Epoch 4/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0505
# Epoch 5/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0617
# Epoch 6/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0500
# Epoch 7/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0642
# Epoch 8/800
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0522
# Epoch 9/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0734
# Epoch 10/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0651
# Epoch 11/800
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0504
# Epoch 12/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0543
# ...

# %%
test=[]
outpt=[]

predicted_V=[]
predicted_W=[]

V_graph=[]
W_graph=[]

for i in range (len(xarray)):
    test = [[xarray[i][0],xarray[i][1],xarray[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [',i,'] data:  V = ', yarray[i][0]*VLmed, ', W= ', yarray[i][1]*Wdmed,
    ',  predicted V = ', outpt[0][0]*VLmed, ', predicted W =',outpt[0][1]*Wdmed )
    
    predicted_V.append(outpt[0][0]*VLmed)
    predicted_W.append(outpt[0][1]*Wdmed)
    
    V_graph.append(yarray[i][0]*VLmed)
    W_graph.append(yarray[i][1]*Wdmed)
# Out:
# row [ 0 ] data:  V =  27.099999999999998 , W=  82.7 ,  predicted V =  28.090865802764892 , predicted W = 77.04321022629738
# row [ 1 ] data:  V =  19.4 , W=  84.7 ,  predicted V =  18.92417719364166 , predicted W = 87.00625684857368
# row [ 2 ] data:  V =  28.3 , W=  119.6 ,  predicted V =  29.167152690887452 , predicted W = 111.87425037622451
# row [ 3 ] data:  V =  30.099999999999998 , W=  135.5 ,  predicted V =  30.886442041397093 , predicted W = 127.73507225513457
# row [ 4 ] data:  V =  25.0 , W=  70.3 ,  predicted V =  26.262279465794563 , predicted W = 68.25943942666053
# row [ 5 ] data:  V =  26.4 , W=  156.7 ,  predicted V =  25.095994052290916 , predicted W = 140.58172785043715
# row [ 6 ] data:  V =  23.6 , W=  83.7 ,  predicted V =  22.64519354701042 , predicted W = 75.58520689606667
# row [ 7 ] data:  V =  29.300000000000004 , W=  128.8 ,  predicted V =  30.620990061759947 , predicted W = 120.74415248632431
# ...

# %%
print(predicted_W)
print(W_graph)
# Out:
# [77.04321022629738, 87.00625684857368, 111.87425037622451, 127.73507225513457, 68.25943942666053, 140.58172785043715, 75.58520689606667, 120.74415248632431, 79.0522665977478, 102.71830592155456, 73.16477149128913, 100.20848153829574, 88.73798782229423, 107.33078198432922, 174.33281525373457, 65.83415331840514, 80.98758988976478, 158.88114693164823, 69.4204102575779, 91.76637806296348, 90.53997344970702, 79.76147166490554, 131.45338407754898, 91.48831879496574]
# [82.7, 84.7, 119.6, 135.5, 70.3, 156.7, 83.7, 128.8, 80.3, 105.20000000000002, 75.2, 100.5, 88.7, 118.20000000000002, 189.4, 62.2, 83.1, 167.5, 72.5, 99.7, 92.8, 81.1, 138.6, 93.5]

# %%
import matplotlib.pyplot as plt

plt.scatter(predicted_W, W_graph, color='blue')
plt.plot([60,200],[60,200], color='red')
plt.loglog()
plt.xlim(xmax = 200, xmin = 60)
plt.ylim(ymax = 200, ymin = 60)
plt.xlabel("Predicted Power Output (W)",fontsize=15)
plt.ylabel('Data value Power Output (W)',fontsize=15)
plt.title('Training Data | Predicted Power Output Vs Data value Power Output')
plt.show()

# %%
s=0
for i in range (len(predicted_W)):
    s=s+abs(predicted_W[i]-W_graph[i])
mae=s/len(predicted_W)
print('MAE =',mae)
# Out:
# MAE = 5.331218439837303

# %%
test=[]
outpt=[]

predicted_V=[]
predicted_W=[]

V_graph=[]
W_graph=[]

for i in range (len(xdata_normalized)):
    test = [[xdata_normalized[i][0],xdata_normalized[i][1],xdata_normalized[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [',i,'] data:  V = ', ydata_normalized[i][0]*VLmed, ', W= ', ydata_normalized[i][1]*Wdmed,
    ',  predicted V = ', outpt[0][0]*VLmed, ', predicted W =',outpt[0][1]*Wdmed )
    
    predicted_V.append(outpt[0][0]*VLmed)
    predicted_W.append(outpt[0][1]*Wdmed)
    
    V_graph.append(ydata_normalized[i][0]*VLmed)
    W_graph.append(ydata_normalized[i][1]*Wdmed)
# Out:
# row [ 0 ] data:  V =  18.9 , W=  80.3 ,  predicted V =  18.219396322965622 , predicted W = 79.0522665977478
# row [ 1 ] data:  V =  23.5 , W=  124.6 ,  predicted V =  19.841668379306793 , predicted W = 92.05885221362114
# row [ 2 ] data:  V =  24.8 , W=  138.6 ,  predicted V =  23.54213764965534 , predicted W = 131.45338407754898
# row [ 3 ] data:  V =  25.6 , W=  146.9 ,  predicted V =  24.403202790021897 , predicted W = 146.86815602779387
# row [ 4 ] data:  V =  19.2 , W=  83.1 ,  predicted V =  18.668942788243292 , predicted W = 80.98758988976478
# row [ 5 ] data:  V =  25.0 , W=  140.5 ,  predicted V =  22.234836784005164 , predicted W = 109.61472945213318
# row [ 6 ] data:  V =  26.5 , W=  157.6 ,  predicted V =  25.777085790038107 , predicted W = 147.8400627851486
# row [ 7 ] data:  V =  27.3 , W=  167.5 ,  predicted V =  25.925030148029325 , predicted W = 158.88114693164823
# ...

# %%
print(predicted_W)
print(W_graph)
# Out:
# [79.0522665977478, 92.05885221362114, 131.45338407754898, 146.86815602779387, 80.98758988976478, 109.61472945213318, 147.8400627851486, 158.88114693164823, 87.00625684857368, 140.58172785043715, 164.0388945698738, 174.33281525373457, 73.16477149128913, 76.50283111929893, 91.76637806296348, 102.45075949430465, 75.58520689606667, 85.95537252426146, 103.6878857731819, 111.87425037622451, 82.39308868050574, 107.33078198432922, 120.74415248632431, 127.73507225513457, 65.83415331840514, 69.4204102575779, 76.72793239951133, 79.76147166490554, 68.25943942666053, 77.04321022629738, 88.73798782229423, 90.53997344970702, 73.8612143754959, 91.48831879496574, 100.20848153829574, 102.71830592155456]
# [80.3, 124.6, 138.6, 146.9, 83.1, 140.5, 157.6, 167.5, 84.7, 156.7, 177.7, 189.4, 75.2, 92.2, 99.7, 104.59999999999998, 83.7, 104.9, 113.80000000000001, 119.6, 92.0, 118.20000000000002, 128.8, 135.5, 62.2, 72.5, 77.6, 81.1, 70.3, 82.7, 88.7, 92.8, 78.6, 93.5, 100.5, 105.20000000000002]

# %%
import matplotlib.pyplot as plt

plt.scatter(predicted_W, W_graph, color='blue')
plt.plot([60,200],[60,200], color='red')
plt.loglog()
plt.xlim(xmax = 200, xmin = 60)
plt.ylim(ymax = 200, ymin = 60)
plt.xlabel("Predicted Power Output (W)",fontsize=15)
plt.ylabel('Data value Power Output (W)',fontsize=15)
plt.title('Predicted Power Output Vs Data value Power Output')
plt.show()

# %%
s=0
for i in range (len(predicted_W)):
    s=s+abs(predicted_W[i]-W_graph[i])
mae=s/len(predicted_W)
print('MAE =',mae)
# Out:
# MAE = 7.693040642804576

# %%
test=[]
outpt=[]

predicted_V=[]
predicted_W=[]

V_graph=[]
W_graph=[]

for i in range (len(validation_dataX)):
    test = [[validation_dataX[i][0],validation_dataX[i][1],validation_dataX[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [',i,'] data:  V = ', validation_dataY[i][0]*VLmed, ', W= ', validation_dataY[i][1]*Wdmed,
    ',  predicted V = ', outpt[0][0]*VLmed, ', predicted W =',outpt[0][1]*Wdmed )
    
    predicted_V.append(outpt[0][0]*VLmed)
    predicted_W.append(outpt[0][1]*Wdmed)
    
    V_graph.append(validation_dataY[i][0]*VLmed)
    W_graph.append(validation_dataY[i][1]*Wdmed)
# Out:
# row [ 0 ] data:  V =  23.5 , W=  124.6 ,  predicted V =  19.841668379306793 , predicted W = 92.05885221362114
# row [ 1 ] data:  V =  25.6 , W=  146.9 ,  predicted V =  24.403202790021897 , predicted W = 146.86815602779387
# row [ 2 ] data:  V =  25.0 , W=  140.5 ,  predicted V =  22.234836784005164 , predicted W = 109.61472945213318
# row [ 3 ] data:  V =  26.5 , W=  157.6 ,  predicted V =  25.777085790038107 , predicted W = 147.8400627851486
# row [ 4 ] data:  V =  28.100000000000005 , W=  177.7 ,  predicted V =  27.41999321579933 , predicted W = 164.0388945698738
# row [ 5 ] data:  V =  24.8 , W=  92.2 ,  predicted V =  24.529832288622856 , predicted W = 76.50283111929893
# row [ 6 ] data:  V =  26.4 , W=  104.59999999999998 ,  predicted V =  27.16488966345787 , predicted W = 102.45075949430465
# row [ 7 ] data:  V =  26.5 , W=  104.9 ,  predicted V =  26.389670434594155 , predicted W = 85.95537252426146
# ...

# %%
print(predicted_W)
print(W_graph)
# Out:
# [92.05885221362114, 146.86815602779387, 109.61472945213318, 147.8400627851486, 164.0388945698738, 76.50283111929893, 102.45075949430465, 85.95537252426146, 103.6878857731819, 82.39308868050574, 76.72793239951133, 73.8612143754959]
# [124.6, 146.9, 140.5, 157.6, 177.7, 92.2, 104.59999999999998, 104.9, 113.80000000000001, 92.0, 77.6, 78.6]

# %%
import matplotlib.pyplot as plt

plt.scatter(predicted_W, W_graph, color='blue')
plt.plot([60,200],[60,200], color='red')
plt.loglog()
plt.xlim(xmax = 200, xmin = 60)
plt.ylim(ymax = 200, ymin = 60)
plt.xlabel("Predicted Power Output (W)",fontsize=15)
plt.ylabel('Data value Power Output (W)',fontsize=15)
plt.title('Validation | Predicted Power Output Vs Data value Power Output')
plt.show()

# %%
s=0
for i in range (len(predicted_W)):
    s=s+abs(predicted_W[i]-W_graph[i])
mae=s/len(predicted_W)
print('MAE =',mae)
# Out:
# MAE = 12.41668504873912

# %%
#Part 1 input HI FLUX DATA: Air temp (degC), ID (W/sqm), load resistance (ohms)

xdata_hitflux = [[-10.0, 1550, 4.464], 
  [-10.0, 1850, 4.464], 
  [10.0, 1550, 4.464], 
  [10.0, 1850, 4.464], 
  [30.0, 1550, 4.464], 
  [30.0, 1850, 4.464], 
  [-10.0, 1550, 6.696], 
  [-10.0, 1850, 6.696], 
  [10.0, 1550, 6.696], 
  [10.0, 1850, 6.696], 
  [30.0, 1550, 6.696], 
  [30.0, 1850, 6.696], 
  [-10.0, 1550, 8.928], 
  [-10.0, 1850, 8.928],   
  [10.0, 1550, 8.928], 
  [10.0, 1850, 8.928], 
  [30.0, 1550, 8.928], 
  [30.0, 1850, 8.928]]
 
#Part 1 output HI FLUX DATA: load voltage (V) and Power out (W)
ydata_hitflux = [[26.1, 152.8], 
 [26.5, 172.7], 
 [27.9, 191.4], 
 [28.3, 198.0], 
 [29.6, 217.8], 
 [30.1, 224.4],  
 [26.9, 118.8], 
 [27.2, 122.1], 
 [28.8, 136.4], 
 [29.1, 139.7], 
 [30.6, 154.0], 
 [31.0, 158.4],  
 [27.3, 92.4], 
 [27.6, 94.6], 
 [29.2, 105.6], 
 [29.6, 107.8], 
 [31.1, 119.9], 
 [31.5, 123.2]]


xarray_hitflux= numpy.array(xdata_hitflux)
yarray_hitflux= numpy.array(ydata_hitflux)
print (xdata_hitflux)
print (xarray_hitflux)
print (ydata_hitflux)
print (yarray_hitflux)
# Out:
# [[-10.0, 1550, 4.464], [-10.0, 1850, 4.464], [10.0, 1550, 4.464], [10.0, 1850, 4.464], [30.0, 1550, 4.464], [30.0, 1850, 4.464], [-10.0, 1550, 6.696], [-10.0, 1850, 6.696], [10.0, 1550, 6.696], [10.0, 1850, 6.696], [30.0, 1550, 6.696], [30.0, 1850, 6.696], [-10.0, 1550, 8.928], [-10.0, 1850, 8.928], [10.0, 1550, 8.928], [10.0, 1850, 8.928], [30.0, 1550, 8.928], [30.0, 1850, 8.928]]
# [[ -10.    1550.       4.464]
#  [ -10.    1850.       4.464]
#  [  10.    1550.       4.464]
#  [  10.    1850.       4.464]
#  [  30.    1550.       4.464]
#  [  30.    1850.       4.464]
#  [ -10.    1550.       6.696]
#  [ -10.    1850.       6.696]
#  [  10.    1550.       6.696]
#  [  10.    1850.       6.696]
#  [  30.    1550.       6.696]
#  [  30.    1850.       6.696]
#  [ -10.    1550.       8.928]
#  [ -10.    1850.       8.928]
#  [  10.    1550.       8.928]
#  [  10.    1850.       8.928]
#  [  30.    1550.       8.928]
#  [  30.    1850.       8.928]]
# ...

# %%
xdata_normalized_hitflux=[]
for i in range (len(xdata_hitflux)):
    xdata_normalized_hitflux.append([xdata_hitflux[i][0]/median(T),xdata_hitflux[i][1]/median(I),xdata_hitflux[i][2]/median(R)])
for j in range (len(xdata_normalized_hitflux)):
    print(xdata_normalized_hitflux[j])
# Out:
# [-1.0, 1.9375, 0.6666666666666667]
# [-1.0, 2.3125, 0.6666666666666667]
# [1.0, 1.9375, 0.6666666666666667]
# [1.0, 2.3125, 0.6666666666666667]
# [3.0, 1.9375, 0.6666666666666667]
# [3.0, 2.3125, 0.6666666666666667]
# [-1.0, 1.9375, 1.0]
# [-1.0, 2.3125, 1.0]
# [1.0, 1.9375, 1.0]
# [1.0, 2.3125, 1.0]
# [3.0, 1.9375, 1.0]
# [3.0, 2.3125, 1.0]
# [-1.0, 1.9375, 1.3333333333333335]
# [-1.0, 2.3125, 1.3333333333333335]
# [1.0, 1.9375, 1.3333333333333335]
# [1.0, 2.3125, 1.3333333333333335]
# [3.0, 1.9375, 1.3333333333333335]
# [3.0, 2.3125, 1.3333333333333335]

# %%
ydata_normalized_hitflux=[]
for i in range (len(ydata_hitflux)):
    ydata_normalized_hitflux.append([ydata_hitflux[i][0]/median(V),ydata_hitflux[i][1]/median(W)])
for j in range (len(ydata_normalized_hitflux)):
    print(ydata_normalized_hitflux[j])
# Out:
# [0.9867674858223063, 1.5264735264735267]
# [1.001890359168242, 1.7252747252747254]
# [1.054820415879017, 1.9120879120879122]
# [1.0699432892249527, 1.978021978021978]
# [1.1190926275992439, 2.175824175824176]
# [1.1379962192816635, 2.241758241758242]
# [1.0170132325141776, 1.1868131868131868]
# [1.0283553875236295, 1.2197802197802199]
# [1.0888468809073724, 1.3626373626373627]
# [1.1001890359168243, 1.3956043956043955]
# [1.1568998109640833, 1.5384615384615385]
# [1.172022684310019, 1.5824175824175826]
# [1.0321361058601135, 0.9230769230769232]
# [1.0434782608695652, 0.945054945054945]
# [1.1039697542533082, 1.054945054945055]
# [1.1190926275992439, 1.0769230769230769]
# [1.175803402646503, 1.197802197802198]
# [1.1909262759924386, 1.2307692307692308]

# %%
test=[]
outpt=[]

predicted_V=[]
predicted_W=[]

V_graph=[]
W_graph=[]

for i in range (len(xdata_normalized_hitflux)):
    test = [[xdata_normalized_hitflux[i][0],xdata_normalized_hitflux[i][1],xdata_normalized_hitflux[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [',i,'] data:  V = ', ydata_normalized_hitflux[i][0]*VLmed, ', W= ', ydata_normalized_hitflux[i][1]*Wdmed,
    ',  predicted V = ', outpt[0][0]*VLmed, ', predicted W =',outpt[0][1]*Wdmed )
    
    predicted_V.append(outpt[0][0]*VLmed)
    predicted_W.append(outpt[0][1]*Wdmed)
    
    V_graph.append(ydata_normalized_hitflux[i][0]*VLmed)
    W_graph.append(ydata_normalized_hitflux[i][1]*Wdmed)
# Out:
# row [ 0 ] data:  V =  26.1 , W=  152.8 ,  predicted V =  24.67956759929657 , predicted W = 157.22971210479736
# row [ 1 ] data:  V =  26.5 , W=  172.7 ,  predicted V =  24.97256020605564 , predicted W = 166.92364909648893
# row [ 2 ] data:  V =  27.900000000000002 , W=  191.4 ,  predicted V =  25.721755442023277 , predicted W = 165.78990902900694
# row [ 3 ] data:  V =  28.3 , W=  198.0 ,  predicted V =  25.690445300936698 , predicted W = 172.76733274459838
# row [ 4 ] data:  V =  29.6 , W=  217.8 ,  predicted V =  27.551230949163436 , predicted W = 181.44098720550537
# row [ 5 ] data:  V =  30.099999999999998 , W=  224.39999999999998 ,  predicted V =  27.374415361881255 , predicted W = 186.99285300970075
# row [ 6 ] data:  V =  26.9 , W=  118.8 ,  predicted V =  27.167405825853347 , predicted W = 110.74474647045135
# row [ 7 ] data:  V =  27.2 , W=  122.10000000000001 ,  predicted V =  26.994660872220994 , predicted W = 121.97446510791778
# ...

# %%
print(predicted_W)
print(W_graph)
print(max(predicted_W))
print(min(predicted_W))
print(max(W_graph))
print(min(W_graph))
# Out:
# [157.22971210479736, 166.92364909648893, 165.78990902900694, 172.76733274459838, 181.44098720550537, 186.99285300970075, 110.74474647045135, 121.97446510791778, 120.05660554170608, 131.47946928739546, 136.1161093711853, 147.33064942359923, 80.69601666927338, 82.62027820944786, 90.17190469503402, 90.46794080138206, 103.93536114692688, 105.66148368120193]
# [152.8, 172.7, 191.4, 198.0, 217.8, 224.39999999999998, 118.8, 122.10000000000001, 136.4, 139.7, 154.0, 158.4, 92.4, 94.6, 105.6, 107.79999999999998, 119.9, 123.2]
# 186.99285300970075
# 80.69601666927338
# 224.39999999999998
# 92.4

# %%
import matplotlib.pyplot as plt

plt.scatter(predicted_W, W_graph, color='blue')
plt.plot([80,230],[80,230], color='red')
plt.loglog()
plt.xlim(xmax = 230, xmin = 80)
plt.ylim(ymax = 230, ymin = 80)
plt.xlabel("Predicted Power Output (W)",fontsize=15)
plt.ylabel('Data value Power Output (W)',fontsize=15)
plt.title('Hitflux | Predicted Power Output Vs Data value Power Output')
plt.show()

# %%
s=0
for i in range (len(predicted_W)):
    s=s+abs(predicted_W[i]-W_graph[i])
mae=s/len(predicted_W)
print('MAE =',mae)
# Out:
# MAE = 15.914441700776422

# %%
import matplotlib.pyplot as plt

x=np.linspace(500/IDmed,1800/IDmed,num=35)
y=np.linspace(4/RLmed,8/RLmed,num=35)

Z=np.zeros((len(y),len(x)))
for i in range (len(x)):
    for j in range (len(y)):
        Z[j][i]=model.predict(np.array([[20/Tamed, x[i], y[j]]]))[0][1]*Wdmed
        
X,Y=np.meshgrid(x*IDmed,y*RLmed)

#Create the 3D figure
fig=plt.figure()
ax=plt.axes(projection='3d') #Define 3D axes
fig.set_size_inches(15,15) #Set the size of the figure

#Plot the surface
surf=ax.plot_surface(X,Y,Z,cmap='viridis',linewidth=0,antialiased=False)

#Label the figure
ax.set_xlabel(r'Id (W/m^2)',fontsize=20,labelpad=20)
ax.set_ylabel(r'Rl (Ohms)',fontsize=15,labelpad=20)
ax.zaxis.set_rotate_label(False) #disable automatic rotation
ax.set_zlabel(r'Predicted Power Output W (W)',fontsize=20, rotation=90,labelpad=40) #rotate the text to align with axis
ax.zaxis.set_tick_params(pad=20)

fig.colorbar(surf,shrink=0.5,aspect=10,location = 'left') #add colorbar
plt.title("Power Output prediction")

plt.show()

# %%
import matplotlib.pyplot as plt

x=np.linspace(4/RLmed,8/RLmed,num=35)
y=np.linspace(500/IDmed,1800/IDmed,num=35)

Z=np.zeros((len(y),len(x)))
for i in range (len(x)):
    for j in range (len(y)):
        Z[j][i]=model.predict(np.array([[20/Tamed, y[j], x[i]]]))[0][1]*Wdmed
        
X,Y=np.meshgrid(x*RLmed,y*IDmed)

#Create the 3D figure
fig=plt.figure()
ax=plt.axes(projection='3d') #Define 3D axes
fig.set_size_inches(15,15) #Set the size of the figure

#Plot the surface
surf=ax.plot_surface(X,Y,Z,cmap='viridis',linewidth=0,antialiased=False)

#Label the figure
ax.set_xlabel(r'Rl (Ohms)',fontsize=20,labelpad=20)
ax.set_ylabel(r'Id (W/m^2)',fontsize=15,labelpad=20)
ax.zaxis.set_rotate_label(False) #disable automatic rotation
ax.set_zlabel(r'Predicted Power Output W (W)',fontsize=20, rotation=90,labelpad=40) #rotate the text to align with axis
ax.zaxis.set_tick_params(pad=20)

fig.colorbar(surf,shrink=0.5,aspect=10,location = 'left') #add colorbar
plt.title("Power Output prediction")

plt.show()

# %%
#Neural Network 
#import useful packages
from tensorflow import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf

#the follwoing 2 lines are only needed for Mac OS machines
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# define meadian values of input variables - add your values here
Tamed = median(T)  #make sure Tamed does not = 0
IDmed = median(I)
RLmed = median(R)

#create input data array
xarray= np.array(training_dataX)
print (training_dataX)
print (xarray)

# define meadian values of output variables - add your values here
VLmed = median(V)
Wdmed = median(W)

#create output data array
yarray= np.array(training_dataY)
print (training_dataY)
print (yarray)
# Out:
# [[1.0, 0.8125, 1.3333333333333335], [3.0, 0.4375, 0.6666666666666667], [1.0, 1.5625, 1.0], [3.0, 1.5625, 1.0], [1.0, 0.4375, 1.3333333333333335], [3.0, 0.8125, 0.6666666666666667], [1.0, 0.4375, 1.0], [3.0, 1.1875, 1.0], [-1.0, 0.4375, 0.6666666666666667], [3.0, 1.5625, 1.3333333333333335], [-1.0, 0.4375, 1.0], [3.0, 1.1875, 1.3333333333333335], [1.0, 1.1875, 1.3333333333333335], [3.0, 0.8125, 1.0], [3.0, 1.5625, 0.6666666666666667], [-1.0, 0.4375, 1.3333333333333335], [1.0, 0.4375, 0.6666666666666667], [1.0, 1.5625, 0.6666666666666667], [-1.0, 0.8125, 1.3333333333333335], [-1.0, 1.1875, 1.0], [1.0, 1.5625, 1.3333333333333335], [-1.0, 1.5625, 1.3333333333333335], [-1.0, 1.1875, 0.6666666666666667], [3.0, 0.8125, 1.3333333333333335]]
# [[ 1.          0.8125      1.33333333]
#  [ 3.          0.4375      0.66666667]
#  [ 1.          1.5625      1.        ]
#  [ 3.          1.5625      1.        ]
#  [ 1.          0.4375      1.33333333]
#  [ 3.          0.8125      0.66666667]
# ...

# %%
# define neural network model

#As seen below, we have created four dense layers. 
#A dense layer is a layer in neural network that’s fully connected. 
#In other words, all the neurons in one layer are connected to all other neurons in the next layer.
#In the first layer, we need to provide the input shape, which is 1 in our case. 
#The activation function we have chosen is elu, which stands for exponential linear unit. .

from keras import backend as K
#initialize weights with values between -0.2 and 0.5
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.5)

model = keras.Sequential([
    keras.layers.Dense(6, activation=K.elu, input_shape=[3],  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(12, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(16, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(2,  kernel_initializer=initializer)
  ])

# %%
#We’re using RMSprop as our optimizer here. RMSprop stands for Root Mean Square Propagation. 
#It’s one of the most popular gradient descent optimization algorithms for deep learning networks. 
#RMSprop is an optimizer that’s reliable and fast.
#We’re compiling the mode using the model.compile function. The loss function used here 
#is mean squared error. After the compilation of the model, we’ll use the fit method with ~500 epochs.
#Number of epochs can be varied.

#from tf.keras import optimizers
rms = keras.optimizers.RMSprop(0.020)
model.compile(loss='mean_absolute_error',optimizer=rms)

# %%
#After the compilation of the model, we’ll use the fit method with 500 epochs.
#I started with epochs value of 100 and then tested the model after training. 
#The prediction was not that good. Then I modified the number of epochs to 200 and tested the model again. 
#Accuracy had improved slightly, but figured I’d give it one more try. Finally, at 500 epochs 
#I found acceptable prediction accuracy.

#The fit method takes three parameters; namely, x, y, and number of epochs. 
#During model training, if all the batches of data are seen by the model once, 
#we say that one epoch has been completed.

# Add an early stopping callback
es = keras.callbacks.EarlyStopping(
    monitor='loss', 
    mode='min', 
    patience = 80, 
    restore_best_weights = True, 
    verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss', 
                     mode='min',  verbose=1, save_best_only=True)

historyData = model.fit(xarray,yarray,epochs=800,callbacks=[es])

loss_hist = historyData.history['loss']
#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))

model.save('./best_model')
# Out:
# Epoch 1/800
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0337
# Epoch 2/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0489
# Epoch 3/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0856
# Epoch 4/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0728
# Epoch 5/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0477
# Epoch 6/800
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0491
# Epoch 7/800
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0959
# Epoch 8/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0919
# Epoch 9/800
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0448
# Epoch 10/800
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0614
# Epoch 11/800
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0691
# Epoch 12/800
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0469
# ...

# %%
test=[]
outpt=[]

predicted_V=[]
predicted_W=[]

V_graph=[]
W_graph=[]

for i in range (len(xarray)):
    test = [[xarray[i][0],xarray[i][1],xarray[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [',i,'] data:  V = ', yarray[i][0]*VLmed, ', W= ', yarray[i][1]*Wdmed,
    ',  predicted V = ', outpt[0][0]*VLmed, ', predicted W =',outpt[0][1]*Wdmed )
    
    predicted_V.append(outpt[0][0]*VLmed)
    predicted_W.append(outpt[0][1]*Wdmed)
    
    V_graph.append(yarray[i][0]*VLmed)
    W_graph.append(yarray[i][1]*Wdmed)
# Out:
# row [ 0 ] data:  V =  27.099999999999998 , W=  82.7 ,  predicted V =  27.949576032161712 , predicted W = 89.48814046382904
# row [ 1 ] data:  V =  19.4 , W=  84.7 ,  predicted V =  17.385275876522062 , predicted W = 77.4870406448841
# row [ 2 ] data:  V =  28.3 , W=  119.6 ,  predicted V =  29.88736160993576 , predicted W = 134.07095016241072
# row [ 3 ] data:  V =  30.099999999999998 , W=  135.5 ,  predicted V =  32.253840720653535 , predicted W = 145.94541261196136
# row [ 4 ] data:  V =  25.0 , W=  70.3 ,  predicted V =  24.937545189261435 , predicted W = 74.88291094899178
# row [ 5 ] data:  V =  26.4 , W=  156.7 ,  predicted V =  26.993150544166564 , predicted W = 143.63512934446334
# row [ 6 ] data:  V =  23.6 , W=  83.7 ,  predicted V =  21.43821125626564 , predicted W = 81.5016093313694
# row [ 7 ] data:  V =  29.300000000000004 , W=  128.8 ,  predicted V =  30.934722089767455 , predicted W = 131.7030550956726
# ...

# %%
print(predicted_W)
print(W_graph)
# Out:
# [89.48814046382904, 77.4870406448841, 134.07095016241072, 145.94541261196136, 74.88291094899178, 143.63512934446334, 81.5016093313694, 131.7030550956726, 81.10159037113189, 115.14904203414916, 79.35544451475143, 111.21814649105072, 100.19314782619476, 114.64146633148192, 182.21423587799072, 71.79881219863891, 81.0998601078987, 174.78646640777586, 80.05990627408028, 108.29419255256653, 103.51038463115691, 94.60157546401024, 148.2756356716156, 100.2600791811943]
# [82.7, 84.7, 119.6, 135.5, 70.3, 156.7, 83.7, 128.8, 80.3, 105.20000000000002, 75.2, 100.5, 88.7, 118.20000000000002, 189.4, 62.2, 83.1, 167.5, 72.5, 99.7, 92.8, 81.1, 138.6, 93.5]

# %%
import matplotlib.pyplot as plt

plt.scatter(predicted_W, W_graph, color='blue')
plt.plot([60,200],[60,200], color='red')
plt.loglog()
plt.xlim(xmax = 200, xmin = 60)
plt.ylim(ymax = 200, ymin = 60)
plt.xlabel("Predicted Power Output (W)",fontsize=15)
plt.ylabel('Data value Power Output (W)',fontsize=15)
plt.title('Training Data | Predicted Power Output Vs Data value Power Output')
plt.show()

# %%
s=0
for i in range (len(predicted_W)):
    s=s+abs(predicted_W[i]-W_graph[i])
mae=s/len(predicted_W)
print('MAE =',mae)
# Out:
# MAE = 7.7173146359622455

# %%
test=[]
outpt=[]

predicted_V=[]
predicted_W=[]

V_graph=[]
W_graph=[]

for i in range (len(xdata_normalized)):
    test = [[xdata_normalized[i][0],xdata_normalized[i][1],xdata_normalized[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [',i,'] data:  V = ', ydata_normalized[i][0]*VLmed, ', W= ', ydata_normalized[i][1]*Wdmed,
    ',  predicted V = ', outpt[0][0]*VLmed, ', predicted W =',outpt[0][1]*Wdmed )
    
    predicted_V.append(outpt[0][0]*VLmed)
    predicted_W.append(outpt[0][1]*Wdmed)
    
    V_graph.append(ydata_normalized[i][0]*VLmed)
    W_graph.append(ydata_normalized[i][1]*Wdmed)
# Out:
# row [ 0 ] data:  V =  18.9 , W=  80.3 ,  predicted V =  16.677390792965888 , predicted W = 81.10159037113189
# row [ 1 ] data:  V =  23.5 , W=  124.6 ,  predicted V =  21.909648019075394 , predicted W = 104.64553277492523
# row [ 2 ] data:  V =  24.8 , W=  138.6 ,  predicted V =  26.28952527940273 , predicted W = 148.2756356716156
# row [ 3 ] data:  V =  25.6 , W=  146.9 ,  predicted V =  27.636846685409544 , predicted W = 158.43043125867842
# row [ 4 ] data:  V =  19.2 , W=  83.1 ,  predicted V =  17.428403782844544 , predicted W = 81.0998601078987
# row [ 5 ] data:  V =  25.0 , W=  140.5 ,  predicted V =  26.045512706041336 , predicted W = 137.70040998458862
# row [ 6 ] data:  V =  26.5 , W=  157.6 ,  predicted V =  29.04224635362625 , predicted W = 166.50108301639557
# row [ 7 ] data:  V =  27.3 , W=  167.5 ,  predicted V =  30.449809038639067 , predicted W = 174.78646640777586
# ...

# %%
print(predicted_W)
print(W_graph)
# Out:
# [81.10159037113189, 104.64553277492523, 148.2756356716156, 158.43043125867842, 81.0998601078987, 137.70040998458862, 166.50108301639557, 174.78646640777586, 77.4870406448841, 143.63512934446334, 171.0060202360153, 182.21423587799072, 79.35544451475143, 87.39670566320419, 108.29419255256653, 120.80787390470505, 81.5016093313694, 99.22341284751892, 121.02675817012786, 134.07095016241072, 80.84779655337333, 114.64146633148192, 131.7030550956726, 145.94541261196136, 71.79881219863891, 80.05990627408028, 90.20029294490814, 94.60157546401024, 74.88291094899178, 89.48814046382904, 100.19314782619476, 103.51038463115691, 77.42024651765823, 100.2600791811943, 111.21814649105072, 115.14904203414916]
# [80.3, 124.6, 138.6, 146.9, 83.1, 140.5, 157.6, 167.5, 84.7, 156.7, 177.7, 189.4, 75.2, 92.2, 99.7, 104.59999999999998, 83.7, 104.9, 113.80000000000001, 119.6, 92.0, 118.20000000000002, 128.8, 135.5, 62.2, 72.5, 77.6, 81.1, 70.3, 82.7, 88.7, 92.8, 78.6, 93.5, 100.5, 105.20000000000002]

# %%
import matplotlib.pyplot as plt

plt.scatter(predicted_W, W_graph, color='blue')
plt.plot([60,200],[60,200], color='red')
plt.loglog()
plt.xlim(xmax = 200, xmin = 60)
plt.ylim(ymax = 200, ymin = 60)
plt.xlabel("Predicted Power Output (W)",fontsize=15)
plt.ylabel('Data value Power Output (W)',fontsize=15)
plt.title('Predicted Power Output Vs Data value Power Output')
plt.show()

# %%
s=0
for i in range (len(predicted_W)):
    s=s+abs(predicted_W[i]-W_graph[i])
mae=s/len(predicted_W)
print('MAE =',mae)
# Out:
# MAE = 8.165051832795143

# %%
test=[]
outpt=[]

predicted_V=[]
predicted_W=[]

V_graph=[]
W_graph=[]

for i in range (len(validation_dataX)):
    test = [[validation_dataX[i][0],validation_dataX[i][1],validation_dataX[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [',i,'] data:  V = ', validation_dataY[i][0]*VLmed, ', W= ', validation_dataY[i][1]*Wdmed,
    ',  predicted V = ', outpt[0][0]*VLmed, ', predicted W =',outpt[0][1]*Wdmed )
    
    predicted_V.append(outpt[0][0]*VLmed)
    predicted_W.append(outpt[0][1]*Wdmed)
    
    V_graph.append(validation_dataY[i][0]*VLmed)
    W_graph.append(validation_dataY[i][1]*Wdmed)
# Out:
# row [ 0 ] data:  V =  23.5 , W=  124.6 ,  predicted V =  21.909648019075394 , predicted W = 104.64553277492523
# row [ 1 ] data:  V =  25.6 , W=  146.9 ,  predicted V =  27.636846685409544 , predicted W = 158.43043125867842
# row [ 2 ] data:  V =  25.0 , W=  140.5 ,  predicted V =  26.045512706041336 , predicted W = 137.70040998458862
# row [ 3 ] data:  V =  26.5 , W=  157.6 ,  predicted V =  29.04224635362625 , predicted W = 166.50108301639557
# row [ 4 ] data:  V =  28.100000000000005 , W=  177.7 ,  predicted V =  30.584972363710403 , predicted W = 171.0060202360153
# row [ 5 ] data:  V =  24.8 , W=  92.2 ,  predicted V =  24.239612820744515 , predicted W = 87.39670566320419
# row [ 6 ] data:  V =  26.4 , W=  104.59999999999998 ,  predicted V =  27.29470220208168 , predicted W = 120.80787390470505
# row [ 7 ] data:  V =  26.5 , W=  104.9 ,  predicted V =  26.65518389940262 , predicted W = 99.22341284751892
# ...

# %%
print(predicted_W)
print(W_graph)
# Out:
# [104.64553277492523, 158.43043125867842, 137.70040998458862, 166.50108301639557, 171.0060202360153, 87.39670566320419, 120.80787390470505, 99.22341284751892, 121.02675817012786, 80.84779655337333, 90.20029294490814, 77.42024651765823]
# [124.6, 146.9, 140.5, 157.6, 177.7, 92.2, 104.59999999999998, 104.9, 113.80000000000001, 92.0, 77.6, 78.6]

# %%
import matplotlib.pyplot as plt

plt.scatter(predicted_W, W_graph, color='blue')
plt.plot([60,200],[60,200], color='red')
plt.loglog()
plt.xlim(xmax = 200, xmin = 60)
plt.ylim(ymax = 200, ymin = 60)
plt.xlabel("Predicted Power Output (W)",fontsize=15)
plt.ylabel('Data value Power Output (W)',fontsize=15)
plt.title('Validation | Predicted Power Output Vs Data value Power Output')
plt.show()

# %%
s=0
for i in range (len(predicted_W)):
    s=s+abs(predicted_W[i]-W_graph[i])
mae=s/len(predicted_W)
print('MAE =',mae)
# Out:
# MAE = 9.060526226460937

# %%
#Part 1 input HI FLUX DATA: Air temp (degC), ID (W/sqm), load resistance (ohms)

xdata_hitflux = [[-10.0, 1550, 4.464], 
  [-10.0, 1850, 4.464], 
  [10.0, 1550, 4.464], 
  [10.0, 1850, 4.464], 
  [30.0, 1550, 4.464], 
  [30.0, 1850, 4.464], 
  [-10.0, 1550, 6.696], 
  [-10.0, 1850, 6.696], 
  [10.0, 1550, 6.696], 
  [10.0, 1850, 6.696], 
  [30.0, 1550, 6.696], 
  [30.0, 1850, 6.696], 
  [-10.0, 1550, 8.928], 
  [-10.0, 1850, 8.928],   
  [10.0, 1550, 8.928], 
  [10.0, 1850, 8.928], 
  [30.0, 1550, 8.928], 
  [30.0, 1850, 8.928]]
 
#Part 1 output HI FLUX DATA: load voltage (V) and Power out (W)
ydata_hitflux = [[26.1, 152.8], 
 [26.5, 172.7], 
 [27.9, 191.4], 
 [28.3, 198.0], 
 [29.6, 217.8], 
 [30.1, 224.4],  
 [26.9, 118.8], 
 [27.2, 122.1], 
 [28.8, 136.4], 
 [29.1, 139.7], 
 [30.6, 154.0], 
 [31.0, 158.4],  
 [27.3, 92.4], 
 [27.6, 94.6], 
 [29.2, 105.6], 
 [29.6, 107.8], 
 [31.1, 119.9], 
 [31.5, 123.2]]


xarray_hitflux= numpy.array(xdata_hitflux)
yarray_hitflux= numpy.array(ydata_hitflux)
print (xdata_hitflux)
print (xarray_hitflux)
print (ydata_hitflux)
print (yarray_hitflux)
# Out:
# [[-10.0, 1550, 4.464], [-10.0, 1850, 4.464], [10.0, 1550, 4.464], [10.0, 1850, 4.464], [30.0, 1550, 4.464], [30.0, 1850, 4.464], [-10.0, 1550, 6.696], [-10.0, 1850, 6.696], [10.0, 1550, 6.696], [10.0, 1850, 6.696], [30.0, 1550, 6.696], [30.0, 1850, 6.696], [-10.0, 1550, 8.928], [-10.0, 1850, 8.928], [10.0, 1550, 8.928], [10.0, 1850, 8.928], [30.0, 1550, 8.928], [30.0, 1850, 8.928]]
# [[ -10.    1550.       4.464]
#  [ -10.    1850.       4.464]
#  [  10.    1550.       4.464]
#  [  10.    1850.       4.464]
#  [  30.    1550.       4.464]
#  [  30.    1850.       4.464]
#  [ -10.    1550.       6.696]
#  [ -10.    1850.       6.696]
#  [  10.    1550.       6.696]
#  [  10.    1850.       6.696]
#  [  30.    1550.       6.696]
#  [  30.    1850.       6.696]
#  [ -10.    1550.       8.928]
#  [ -10.    1850.       8.928]
#  [  10.    1550.       8.928]
#  [  10.    1850.       8.928]
#  [  30.    1550.       8.928]
#  [  30.    1850.       8.928]]
# ...

# %%
xdata_normalized_hitflux=[]
for i in range (len(xdata_hitflux)):
    xdata_normalized_hitflux.append([xdata_hitflux[i][0]/median(T),xdata_hitflux[i][1]/median(I),xdata_hitflux[i][2]/median(R)])
for j in range (len(xdata_normalized_hitflux)):
    print(xdata_normalized_hitflux[j])
# Out:
# [-1.0, 1.9375, 0.6666666666666667]
# [-1.0, 2.3125, 0.6666666666666667]
# [1.0, 1.9375, 0.6666666666666667]
# [1.0, 2.3125, 0.6666666666666667]
# [3.0, 1.9375, 0.6666666666666667]
# [3.0, 2.3125, 0.6666666666666667]
# [-1.0, 1.9375, 1.0]
# [-1.0, 2.3125, 1.0]
# [1.0, 1.9375, 1.0]
# [1.0, 2.3125, 1.0]
# [3.0, 1.9375, 1.0]
# [3.0, 2.3125, 1.0]
# [-1.0, 1.9375, 1.3333333333333335]
# [-1.0, 2.3125, 1.3333333333333335]
# [1.0, 1.9375, 1.3333333333333335]
# [1.0, 2.3125, 1.3333333333333335]
# [3.0, 1.9375, 1.3333333333333335]
# [3.0, 2.3125, 1.3333333333333335]

# %%
ydata_normalized_hitflux=[]
for i in range (len(ydata_hitflux)):
    ydata_normalized_hitflux.append([ydata_hitflux[i][0]/median(V),ydata_hitflux[i][1]/median(W)])
for j in range (len(ydata_normalized_hitflux)):
    print(ydata_normalized_hitflux[j])
# Out:
# [0.9867674858223063, 1.5264735264735267]
# [1.001890359168242, 1.7252747252747254]
# [1.054820415879017, 1.9120879120879122]
# [1.0699432892249527, 1.978021978021978]
# [1.1190926275992439, 2.175824175824176]
# [1.1379962192816635, 2.241758241758242]
# [1.0170132325141776, 1.1868131868131868]
# [1.0283553875236295, 1.2197802197802199]
# [1.0888468809073724, 1.3626373626373627]
# [1.1001890359168243, 1.3956043956043955]
# [1.1568998109640833, 1.5384615384615385]
# [1.172022684310019, 1.5824175824175826]
# [1.0321361058601135, 0.9230769230769232]
# [1.0434782608695652, 0.945054945054945]
# [1.1039697542533082, 1.054945054945055]
# [1.1190926275992439, 1.0769230769230769]
# [1.175803402646503, 1.197802197802198]
# [1.1909262759924386, 1.2307692307692308]

# %%
test=[]
outpt=[]

predicted_V=[]
predicted_W=[]

V_graph=[]
W_graph=[]

for i in range (len(xdata_normalized_hitflux)):
    test = [[xdata_normalized_hitflux[i][0],xdata_normalized_hitflux[i][1],xdata_normalized_hitflux[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [',i,'] data:  V = ', ydata_normalized_hitflux[i][0]*VLmed, ', W= ', ydata_normalized_hitflux[i][1]*Wdmed,
    ',  predicted V = ', outpt[0][0]*VLmed, ', predicted W =',outpt[0][1]*Wdmed )
    
    predicted_V.append(outpt[0][0]*VLmed)
    predicted_W.append(outpt[0][1]*Wdmed)
    
    V_graph.append(ydata_normalized_hitflux[i][0]*VLmed)
    W_graph.append(ydata_normalized_hitflux[i][1]*Wdmed)
# Out:
# row [ 0 ] data:  V =  26.1 , W=  152.8 ,  predicted V =  28.660306775569914 , predicted W = 164.53254463672636
# row [ 1 ] data:  V =  26.5 , W=  172.7 ,  predicted V =  29.458138358592986 , predicted W = 171.09999142885206
# row [ 2 ] data:  V =  27.900000000000002 , W=  191.4 ,  predicted V =  31.220063734054566 , predicted W = 181.81787433624265
# row [ 3 ] data:  V =  28.3 , W=  198.0 ,  predicted V =  31.687855529785157 , predicted W = 188.62845294475554
# row [ 4 ] data:  V =  29.6 , W=  217.8 ,  predicted V =  32.23830231428146 , predicted W = 191.34926204681395
# row [ 5 ] data:  V =  30.099999999999998 , W=  224.39999999999998 ,  predicted V =  32.167540764808656 , predicted W = 198.3620308637619
# row [ 6 ] data:  V =  26.9 , W=  118.8 ,  predicted V =  28.40911304950714 , predicted W = 129.6649482011795
# row [ 7 ] data:  V =  27.2 , W=  122.10000000000001 ,  predicted V =  29.37057716846466 , predicted W = 138.72045385837555
# ...

# %%
print(predicted_W)
print(W_graph)
print(max(predicted_W))
print(min(predicted_W))
print(max(W_graph))
print(min(W_graph))
# Out:
# [164.53254463672636, 171.09999142885206, 181.81787433624265, 188.62845294475554, 191.34926204681395, 198.3620308637619, 129.6649482011795, 138.72045385837555, 145.58839367628096, 155.44138362407682, 159.19480189085004, 168.76831256151198, 98.2526158452034, 104.66023404598235, 108.27884690761566, 117.65968978404999, 122.55728936195374, 132.66714583635328]
# [152.8, 172.7, 191.4, 198.0, 217.8, 224.39999999999998, 118.8, 122.10000000000001, 136.4, 139.7, 154.0, 158.4, 92.4, 94.6, 105.6, 107.79999999999998, 119.9, 123.2]
# 198.3620308637619
# 98.2526158452034
# 224.39999999999998
# 92.4

# %%
import matplotlib.pyplot as plt

plt.scatter(predicted_W, W_graph, color='blue')
plt.plot([80,230],[80,230], color='red')
plt.loglog()
plt.xlim(xmax = 230, xmin = 80)
plt.ylim(ymax = 230, ymin = 80)
plt.xlabel("Predicted Power Output (W)",fontsize=15)
plt.ylabel('Data value Power Output (W)',fontsize=15)
plt.title('Hitflux | Predicted Power Output Vs Data value Power Output')
plt.show()

# %%
s=0
for i in range (len(predicted_W)):
    s=s+abs(predicted_W[i]-W_graph[i])
mae=s/len(predicted_W)
print('MAE =',mae)
# Out:
# MAE = 10.74050270054075

# %%
import matplotlib.pyplot as plt

x=np.linspace(4/RLmed,8/RLmed,num=35)
y=np.linspace(500/IDmed,1800/IDmed,num=35)

Z=np.zeros((len(y),len(x)))
for i in range (len(x)):
    for j in range (len(y)):
        Z[j][i]=model.predict(np.array([[20/Tamed, y[j], x[i]]]))[0][1]*Wdmed
        
X,Y=np.meshgrid(x*RLmed,y*IDmed)

#Create the 3D figure
fig=plt.figure()
ax=plt.axes(projection='3d') #Define 3D axes
fig.set_size_inches(15,15) #Set the size of the figure

#Plot the surface
surf=ax.plot_surface(X,Y,Z,cmap='viridis',linewidth=0,antialiased=False)

#Label the figure
ax.set_xlabel(r'Rl (Ohms)',fontsize=20,labelpad=20)
ax.set_ylabel(r'Id (W/m^2)',fontsize=15,labelpad=20)
ax.zaxis.set_rotate_label(False) #disable automatic rotation
ax.set_zlabel(r'Predicted Power Output W (W)',fontsize=20, rotation=90,labelpad=40) #rotate the text to align with axis
ax.zaxis.set_tick_params(pad=20)

fig.colorbar(surf,shrink=0.5,aspect=10,location = 'left') #add colorbar
plt.title("Power Output prediction")

plt.show()
